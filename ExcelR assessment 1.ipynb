# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\athar\OneDrive\Desktop\python\ExcelR Assignment 1.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.shape
# Out:
# (450, 13)

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102960
# 2      16100             112700           9.456886     10657.910160
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0     160346.50120
# 1      89323.89704
# 2     102042.08980
# 3     112235.92530
# 4      19927.05377

# %%
df.tail()
# Out:
#            Date       Day  SKU City  Volume         BU  Brand      Model  \
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera  M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva  W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva   W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera  M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera    M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 445      2197.632127
# 446     12939.103760
# 447      2593.102394
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df.Date
# Out:
# 0      01-04-2021
# 1      01-04-2021
# 2      01-04-2021
# 3      01-04-2021
# 4      01-04-2021
#           ...
# 445    15-04-2021
# 446    15-04-2021
# 447    15-04-2021
# 448    15-04-2021
# 449    15-04-2021
# Name: Date, Length: 450, dtype: object

# %%
df.Day
# Out:
# 0      Thursday
# 1      Thursday
# 2      Thursday
# 3      Thursday
# 4      Thursday
#          ...
# 445    Thursday
# 446    Thursday
# 447    Thursday
# 448    Thursday
# 449    Thursday
# Name: Day, Length: 450, dtype: object

# %%
df.SKU
# Out:
# 0      M01
# 1      M02
# 2      M03
# 3      M04
# 4      M05
#       ...
# 445    L06
# 446    L07
# 447    L08
# 448    L09
# 449    L10
# Name: SKU, Length: 450, dtype: object

# %%
df.City
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 445    C
# 446    C
# 447    C
# 448    C
# 449    C
# Name: City, Length: 450, dtype: object

# %%
#calculating Mean of every column wich contain numeric values

# %%
mean = df[numerical_cols].mean()
median = df[numerical_cols].median()
mode = df[numerical_cols].mode().iloc[0]
std_dev = df[numerical_cols].std()

print("Mean:\n", mean)
print("Median:\n", median)
print("Mode:\n", mode)
print("Standard Deviation:\n", std_dev)
# Out:
# Mean:
#  Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# Volume                   5.066667
# dtype: float64
# Median:
#  Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# Volume                  4.000000
# dtype: float64
# Mode:
#  Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Volume                   3.000000
# Name: 0, dtype: float64
# Standard Deviation:
#  Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# ...

# %%
#plotting histogram graph

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['Avg Price'],edgecolor='black',bins=30)
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Total Sales Value'], bins=30, color='orange', edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Rate (%)'], bins=30, color='pink', edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Amount'], bins=30, color='black', edgecolor='white')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Net Sales Value'], bins=30, color='yellow', edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Volume'], bins=30, color='grey', edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
# plotting boxplot

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Avg Price'], vert=False)
plt.title('Boxplot of Avg Price')
plt.xlabel('Avg Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Total Sales Value'], vert=False)
plt.title('Boxplot of Total Sales Value')
plt.xlabel('Total Sales Value')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Discount Rate (%)'], vert=False)
plt.title('Boxplot of Discount Rate (%)')
plt.xlabel('Discount Rate (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Discount Amount'], vert=False)
plt.title('Boxplot of Discount Amount')
plt.xlabel('Discount Amount')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Net Sales Value'], vert=False)
plt.title('Boxplot of Net Sales Value')
plt.xlabel('Net Sales Value')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Volume'], vert=False)
plt.title('Boxplot of Volume')
plt.xlabel('Volume')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Volume'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt



# Before Standardization
plt.figure(figsize=(10, 6))
plt.title('Before Standardization')
plt.hist(df['Volume'], bins=30, color='skyblue', edgecolor='black', alpha=0.7, label='Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.legend()
plt.grid(False)
plt.show()

# Standardization
scaler = StandardScaler()
df_standardized = df.copy()
df_standardized['Volume'] = scaler.fit_transform(df[['Volume']])

# After Standardization
plt.figure(figsize=(10, 6))
plt.title('After Standardization')
plt.hist(df_standardized['Volume'], bins=30, color='orange', edgecolor='black', alpha=0.7, label='Volume (Standardized)')
plt.xlabel('Standardized Volume')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
